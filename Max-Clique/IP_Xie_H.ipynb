# %%
import numpy as np
import gurobipy as gp
from gurobipy import GRB

# %%
def generate_adjacency_matrix(file_name):
    input_graph = np.loadtxt(file_name)
    input_graph = input_graph.astype(int)-1
    size = max(max(input_graph[:,0]),max(input_graph[:,1]))+1
    adjacency_matrix = np.zeros((size,size))
    for pair in input_graph:
        adjacency_matrix[pair[0]][pair[1]] = 1
        adjacency_matrix[pair[1]][pair[0]] = 1
    return adjacency_matrix

# %%
def Maximum_Clique_Problem(adj_matrix):
    size = adj_matrix.shape[0]
    m = gp.Model("Mximum Clique Problem")
    m.setParam("TimeLimit",60*60)
    print()
    x = m.addVars(size, vtype = GRB.BINARY, name = "vertex")
    m.setObjective(x.sum(), GRB.MAXIMIZE)
    for i in range(size):
        for j in range(i+1, size):
            if not adj_matrix[i][j]:
                m.addConstr(x[i]+x[j]<=1)
    m.Params.OutputFlag = 0
    m.optimize()
    if m.status == 9:
        print("There was a timeout and the solution may not be optimal!", end="\n \n")
    print("Running time: ", round(m.Runtime, 3)," seconds", end="\n \n")
    print("Cardinality: ",m.objVal, end="\n \n")
    for var in m.getVars():
        if var.x != 0:
            print(var.varName, var.x, end="  ")
    print()

# %% [markdown]
# ## In my code, vertex number starts from 0 not 1.

# %%
def main(file_name):
    adj_matrix = generate_adjacency_matrix(file_name)
    Maximum_Clique_Problem(adj_matrix)

# %%
file_name = ["C125.9.txt","brock200_1.txt","brock200_2.txt","p_hat300_1.txt","p_hat300_3.txt"]

# %%
for i in range(5):
    print(file_name[i], end = "\n")
    main(file_name[i])
    print("-----------------------------------------------------------------------------------------------------------------------------------------------")
# Out:
# C125.9.txt
# Set parameter TimeLimit to value 3600
#
# Running time:  0.574  seconds
#
# Cardinality:  34.0
#
# vertex[0] 1.0  vertex[1] 1.0  vertex[4] 1.0  vertex[6] 1.0  vertex[8] 1.0  vertex[10] 1.0  vertex[17] 1.0  vertex[18] 1.0  vertex[24] 1.0  vertex[28] 1.0  vertex[30] 1.0  vertex[33] 1.0  vertex[39] 1.0  vertex[43] 1.0  vertex[44] 1.0  vertex[47] 1.0  vertex[48] 1.0  vertex[53] 1.0  vertex[67] 1.0  vertex[69] 1.0  vertex[70] 1.0  vertex[76] 1.0  vertex[78] 1.0  vertex[79] 1.0  vertex[98] 1.0  vertex[100] 1.0  vertex[109] 1.0  vertex[113] 1.0  vertex[114] 1.0  vertex[116] 1.0  vertex[120] 1.0  vertex[121] 1.0  vertex[122] 1.0  vertex[124] 1.0
# -----------------------------------------------------------------------------------------------------------------------------------------------
# brock200_1.txt
# Set parameter TimeLimit to value 3600
#
# Running time:  79.677  seconds
#
# Cardinality:  21.0
#
# vertex[17] 1.0  vertex[19] 1.0  vertex[38] 1.0  vertex[67] 1.0  vertex[72] 1.0  vertex[80] 1.0  vertex[84] 1.0  vertex[86] 1.0  vertex[89] 1.0  vertex[91] 1.0  vertex[92] 1.0  vertex[93] 1.0  vertex[101] 1.0  vertex[107] 1.0  vertex[133] 1.0  vertex[134] 1.0  vertex[135] 1.0  vertex[141] 1.0  vertex[149] 1.0  vertex[177] 1.0  vertex[185] 1.0
# -----------------------------------------------------------------------------------------------------------------------------------------------
# brock200_2.txt
# Set parameter TimeLimit to value 3600
#
# Running time:  13.755  seconds
#
# Cardinality:  12.0
#
# vertex[26] 1.0  vertex[47] 1.0  vertex[54] 1.0  vertex[69] 1.0  vertex[104] 1.0  vertex[119] 1.0  vertex[120] 1.0  vertex[134] 1.0  vertex[144] 1.0  vertex[148] 1.0  vertex[157] 1.0  vertex[182] 1.0
# -----------------------------------------------------------------------------------------------------------------------------------------------
# p_hat300_1.txt
# Set parameter TimeLimit to value 3600
#
# Running time:  13.761  seconds
#
# Cardinality:  8.0
#
# vertex[53] 1.0  vertex[123] 1.0  vertex[180] 1.0  vertex[218] 1.0  vertex[246] 1.0  vertex[267] 1.0  vertex[270] 1.0  vertex[286] 1.0
# -----------------------------------------------------------------------------------------------------------------------------------------------
# p_hat300_3.txt
# Set parameter TimeLimit to value 3600
#
# Running time:  287.068  seconds
#
# Cardinality:  36.0
#
# vertex[3] 1.0  vertex[18] 1.0  vertex[19] 1.0  vertex[20] 1.0  vertex[23] 1.0  vertex[32] 1.0  vertex[39] 1.0  vertex[47] 1.0  vertex[48] 1.0  vertex[55] 1.0  vertex[74] 1.0  vertex[75] 1.0  vertex[88] 1.0  vertex[97] 1.0  vertex[138] 1.0  vertex[148] 1.0  vertex[159] 1.0  vertex[165] 1.0  vertex[173] 1.0  vertex[175] 1.0  vertex[189] 1.0  vertex[198] 1.0  vertex[204] 1.0  vertex[218] 1.0  vertex[220] 1.0  vertex[225] 1.0  vertex[234] 1.0  vertex[238] 1.0  vertex[244] 1.0  vertex[246] 1.0  vertex[251] 1.0  vertex[254] 1.0  vertex[272] 1.0  vertex[289] 1.0  vertex[297] 1.0  vertex[298] 1.0
# -----------------------------------------------------------------------------------------------------------------------------------------------
